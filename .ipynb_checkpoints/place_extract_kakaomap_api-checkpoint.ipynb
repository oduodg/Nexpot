# %%
import pandas as pd
import numpy as np
import folium
import simplejson,requests
import sys
import time
import import_ipynb
import YouTubeAPI as youtube
import pymysql as db

# %%
import konlpy
from konlpy.corpus import kolaw
from konlpy.tag import *
import re
from nltk.corpus import stopwords 
from nltk.tokenize import word_tokenize 
import copy
cities = ['서울','부산','대구','인천','광주','대전','울산','세종','경기','강원','충북','충남','전북','전남','경북','경남','제주']

# %%
def cleanText(readData): 
# url 제거
    text = re.sub('http[s]?://(?:[a-zA-Z]|[0-9]|[$\-@\.&+:/?=]|[!*\(\),]|(?:%[0-9a-fA-F][0-9a-fA-F]))+',' ',readData)
# 이메일 제거    
    text = re.sub('[-A-Za-z0-9_]+[-A-Za-z0-9_.][@]{1}[-A-Za-z0-9_]+[-A-Za-z0-9_.][.]{1}[A-Za-z]{1,5}',' ',text)
#텍스트에 포함되어 있는 특수 문자 제거    
    text = re.sub('[:=+,#/\?^$.@*\"※~&%ㆍ!』\\‘’|\(\)\[\]\<\>`\'…》▶✨✔✅❤★♡️♥ㅂㅈㄷㄱㅅㅁㄴㅇㄹㅎㅋㅌ\
                  ㅊㅍㅛㅕㅑㅐㅔㅗㅓㅏㅣㅠㅜㅡ]', ' ', text) 
    text = re.compile("["
        u"\U00010000-\U0010FFFF"  #BMP characters 이외
                           "]+", flags=re.UNICODE).sub(r' ',text)   # 이모티콘 제거
    text = re.sub('\\n\\t\\r★',' ',text)                         # 탭, 줄띄우기 등 제거
    text = re.sub(youtube.channelname ,'', text)
    return text
# 특정 이모티콘 제거 불가 :🌊 🏖 ✉ 등

# %%
titl = youtube.title

# %%
n = 8
desc = youtube.description
titl = youtube.title
print(desc[n])
ex_desc = desc[n].split('\n')  # 각 줄마다 split
vid = youtube.videoID[n]
lex_desc = []
for i in ex_desc:
    # 지번주소 제거
    if bool(re.search('(([가-힣A-Za-z·\d~\-\.]+(읍|동)\s)[\d-]+)|(([가-힣A-Za-z·\d~\-\.]+(읍|동)\s)[\d][^시]+)',i)):
        continue
    # 도로명주소 제거
    if bool(re.search('(([가-힣A-Za-z·\d~\-\.]{2,}(로|길).[\d]+)|([가-힣A-Za-z·\d~\-\.]+(읍|동|면)\s)[\d]+)',i)):
        continue
    else:
        lex_desc.append(i)
spl_place = []
for a in lex_desc:                      # 타임라인에 존재하는 장소 추출
    if bool(re.search('^\d{1,2}:\d{2}',a)):
        sub_place = re.sub('^\d{1,2}:\d{2} ?','', a)
        spl_place.append(sub_place.lower())
    else:
        continue
print(spl_place)
place = []
for j in spl_place:
    i = j
    if '인트로' in i or 'intro' in i:                    # Intro는 제거
        continue
    if '먹방' in i or '여행' in i or '맛집' in i:
        continue
    if "(" in i:
        i = i.split("(")[0]
    if "#" in i:
        i = i.split("#")[1]  # 뒤에 존재하는 장소 추출
    if ":" in i:
        i = i.split(":")[1]
    if "/"in i:
        a = i.split("/")[0]  # / 뒤에 존재하는 장소 추출
        b = i.split("/")[1]
        place.append(a)
        place.append(b)
        continue
    place.append(i)
print(place)
remove_address_place = " ".join(lex_desc)
if len(place) < 2:
    hannanum = Hannanum()              # Mecab 쓰고 싶은데... 설치를 다시 해도 오류가 뜸..;;
    h_place = hannanum.nouns(cleanText(remove_address_place))
    num_place = copy.deepcopy(h_place)
    site = []
    for i in h_place:
        if str.isdigit(i):
            num_place.remove(i)
            continue
        if '여행' in i:
            num_place.remove(i)
            continue
        if len(i) == 1:
            num_place.remove(i)
    place = num_place
    print(h_place)
    print(num_place)
# Out:
# #인천여행브이로그 #월미도브이로그 #인천먹방브이로그
#
# insta 💌
# yein.o.d
# https://www.instagram.com/yein.o.d
# mail 📧
# yeininkong@naver.com
#
# 안녕하세요 😚
# 이번 영상에서는 친구랑 다녀온 인천 여행을 기록해보았습니다~!
#
# 1박2일 동안 차이나타운에서 유명하다는 백짜장도 먹고 월미도에서 일몰보고 테마파크에서 놀이기구도 타고 조개구이도 먹고 알차게 즐기고 왔어요 !
#
# 📍
# #인천역 - #차이나타운 - #청관 (#백짜장)
# - #월미도 - #월미문화의거리 (일몰보고 조형물보고 버스킹본 곳) - #마이랜드 (#바이킹 #디스코팡팡) - #유령치즈조개루프탑 - #호텔다이아몬드 (마이랜드 바로 맞은편)
#
# 인천역에서 내리면 바로 맞은편이 차이나 타운 입구,
# 차이나 타운에서 버스타면 얼마 안가서 월미도,
# 월미도 핫플들은 다 가까이에 붙어있고
# 월미도에서 인천역까지도 버스타고 금방이라
# #1박2일코스 로 아주 좋았고
# #당일치기 로도 완전 가능 !!
#
# 인천 여행 떠나실 분들께 조금이라도 도움이 되었으면 좋겠네요 :)
#
# 오늘도 와주셔서 감사드립니다~~
# 다음 영상에서 또 만나요 💗
# []
# []
# ['여행브이로그', '월미도브이로그', '먹방브이로그', '안녕', '이번', '영상', '친구', '여행', '기록', '1박2', '동안', '차이나타운', '유명', '백짜장', '월미도', '일몰', '테마파크', '놀이기구', '조개구이', '차이나타운', '청관', '백짜장', '월미도', '월미문화의거리', '일몰', '조형물보고', '버스킹본', '곳', '마이랜드', '바이킹', '디스코팡팡', '유령치즈조개루프탑', '호텔다이아몬드', '마이랜드', '맞은편', '역', '맞은편', '차', '타운', '입구', '차', '타운', '버스타', '얼마', '안가', '월미', '월미도', '핫플들', '가까이', '월미도', '역', '버스타', '금방', '1박2일코스', '로', '당일치기', '로', '완전', '가능', '여행', '들', '도움', '오늘', '다음', '영상', '만나요']
# ['월미도브이로그', '먹방브이로그', '안녕', '이번', '영상', '친구', '기록', '1박2', '동안', '차이나타운', '유명', '백짜장', '월미도', '일몰', '테마파크', '놀이기구', '조개구이', '차이나타운', '청관', '백짜장', '월미도', '월미문화의거리', '일몰', '조형물보고', '버스킹본', '마이랜드', '바이킹', '디스코팡팡', '유령치즈조개루프탑', '호텔다이아몬드', '마이랜드', '맞은편', '맞은편', '타운', '입구', '타운', '버스타', '얼마', '안가', '월미', '월미도', '핫플들', '가까이', '월미도', '버스타', '금방', '1박2일코스', '당일치기', '완전', '가능', '도움', '오늘', '다음', '영상', '만나요']

# %%
place_id = []
place_do =  []
place_si =[]
place_name = []
place_address = []
place_phone = []
place_url = []
place_X = []
place_Y = []
category = []
kakao_df = pd.DataFrame(columns=['ID','이름','주소','도', '시',
                                 '전화번호','URL','X좌표','Y좌표'])

url = "https://dapi.kakao.com/v2/local/search/keyword.json?" # kakaomap api에 접근
apikey = "c533ba443ba909af8d277567163d03fe"
sitename = youtube.channelname
query = str(place[4])
r = requests.get( url, params = {'query':query}, 
                  headers={'Authorization' : 'KakaoAK ' + apikey } )


for i in range(len(place)):    
    query = str(place[i])
    r = requests.get( url, params = {'query':query}, 
                     headers={'Authorization' : 'KakaoAK ' + apikey } )
    
    # 장소를 입력하여 json파일 형태의 데이터 생성
    rj = r.json()
    # 입력했을 때 결과가 없으면 생략
    if rj['documents'] == []:                        
        continue
    if rj['documents'][0]['address_name'] in place_address:
        continue
    print(rj['documents'][0])
    if rj['documents'][0]['category_group_name'] in ['학교', '지하철역', '주유소,충전소']:
        continue
        
    if rj['meta']['same_name']['selected_region'] == '':
        if sitename in rj['documents'][0]['address_name']:   # 검색 위치랑 같은 곳만 넣고 아니면 continue
            place_do.append(rj['documents'][0]['address_name'].split()[0])
            place_si.append(rj['documents'][0]['address_name'].split()[1])
        else:
            continue
    elif len(rj['meta']['same_name']['selected_region'].split()) == 1:
        if sitename in rj['documents'][0]['address_name']:
            place_do.append(rj['meta']['same_name']['selected_region'].split()[0])
        else:
            continue
    else:
        if sitename in rj['documents'][0]['address_name']:
            place_do.append(rj['meta']['same_name']['selected_region'].split()[0])
            place_si.append(rj['meta']['same_name']['selected_region'].split()[1])
        else :
            continue
    place_id.append(rj['documents'][0]['id'])         # 이후 list에 결과 append
    place_name.append(rj['documents'][0]['place_name'])
    place_address.append(rj['documents'][0]['address_name'])
    place_phone.append(rj['documents'][0]['phone'])
    place_url.append(rj['documents'][0]['place_url'])
    place_X.append(rj['documents'][0]['x'])
    place_Y.append(rj['documents'][0]['y'])
    category.append(rj['documents'][0]['category_group_name'])
    
kakao_df=pd.DataFrame([place_id,place_name,place_address,place_do,place_si,place_phone,place_url,place_X,place_Y]).T
kakao_df.columns=['placeID','pname','paddress',
                  'pdo', 'psi','pphone','pdaumURL','pX','pY']
print(category)
kakao_df
# Out:
# {'address_name': '서울 종로구 관훈동 155-2', 'category_group_code': '', 'category_group_name': '', 'category_name': '가정,생활 > 복합쇼핑몰', 'distance': '', 'id': '1779571274', 'phone': '02-6954-2910', 'place_name': '안녕인사동', 'place_url': 'http://place.map.kakao.com/1779571274', 'road_address_name': '서울 종로구 인사동길 49', 'x': '126.983529078926', 'y': '37.574514077728'}
# {'address_name': '대구 중구 완전동 5-39', 'category_group_code': '', 'category_group_name': '', 'category_name': '가정,생활 > 취미', 'distance': '', 'id': '1765893114', 'phone': '', 'place_name': '이번주말', 'place_url': 'http://place.map.kakao.com/1765893114', 'road_address_name': '대구 중구 교동3길 37', 'x': '128.59874156197887', 'y': '35.87251687794962'}
# {'address_name': '세종특별자치시 장군면 금암리 180-1', 'category_group_code': '', 'category_group_name': '', 'category_name': '교육,학문 > 학교 > 전문대학', 'distance': '', 'id': '8663308', 'phone': '044-850-9000', 'place_name': '한국영상대학교', 'place_url': 'http://place.map.kakao.com/8663308', 'road_address_name': '세종특별자치시 장군면 대학길 300', 'x': '127.20919616105093', 'y': '36.46358032130445'}
# {'address_name': '경기 고양시 일산동구 풍동 655-10', 'category_group_code': 'FD6', 'category_group_name': '음식점', 'category_name': '음식점 > 한식 > 육류,고기', 'distance': '', 'id': '9462030', 'phone': '031-906-7979', 'place_name': '친구', 'place_url': 'http://place.map.kakao.com/9462030', 'road_address_name': '경기 고양시 일산동구 애니골길43번길 56', 'x': '126.78879505777064', 'y': '37.67351669936616'}
# {'address_name': '부산 강서구 녹산동 855', 'category_group_code': 'CE7', 'category_group_name': '카페', 'category_name': '음식점 > 카페', 'distance': '', 'id': '39944141', 'phone': '', 'place_name': '기록', 'place_url': 'http://place.map.kakao.com/39944141', 'road_address_name': '부산 강서구 낙동남로 449-11', 'x': '128.868893761438', 'y': '35.1126758747867'}
# {'address_name': '경북 포항시 북구 송라면 방석리 106', 'category_group_code': 'AD5', 'category_group_name': '숙박', 'category_name': '여행 > 숙박 > 펜션', 'distance': '', 'id': '199239078', 'phone': '010-5524-3985', 'place_name': '풀빌라1박2일', 'place_url': 'http://place.map.kakao.com/199239078', 'road_address_name': '경북 포항시 북구 송라면 해안로 2845-1', 'x': '129.381468374215', 'y': '36.2350909140173'}
# {'address_name': '경기 안양시 동안구 관양동', 'category_group_code': 'AT4', 'category_group_name': '관광명소', 'category_name': '여행 > 관광,명소 > 테마거리 > 카페거리', 'distance': '', 'id': '612882143', 'phone': '', 'place_name': '동편마을카페거리', 'place_url': 'http://place.map.kakao.com/612882143', 'road_address_name': '', 'x': '126.970398096811', 'y': '37.4071259467104'}
# {'address_name': '인천 중구 북성동2가 14', 'category_group_code': 'AT4', 'category_group_name': '관광명소', 'category_name': '여행 > 관광,명소 > 테마거리 > 먹자골목', 'distance': '', 'id': '12706268', 'phone': '032-777-4000', 'place_name': '인천차이나타운', 'place_url': 'http://place.map.kakao.com/12706268', 'road_address_name': '', 'x': '126.6186319858808', 'y': '37.475536458050655'}
# {'address_name': '경남 양산시 덕계동 728-2', 'category_group_code': 'OL7', 'category_group_name': '주유소,충전소', 'category_name': '교통,수송 > 자동차 > 주유,가스 > 주유소 > S-oil주유소', 'distance': '', 'id': '10679040', 'phone': '055-387-3350', 'place_name': '유명주유소', 'place_url': 'http://place.map.kakao.com/10679040', 'road_address_name': '경남 양산시 웅상대로 811', 'x': '129.15185883979552', 'y': '35.37277681885474'}
# {'address_name': '경남 김해시 삼문동 74-1', 'category_group_code': 'FD6', 'category_group_name': '음식점', 'category_name': '음식점 > 중식 > 중국요리', 'distance': '', 'id': '846617015', 'phone': '055-313-5989', 'place_name': '장유백짜장', 'place_url': 'http://place.map.kakao.com/846617015', 'road_address_name': '경남 김해시 능동로7번길 8-4', 'x': '128.794301290409', 'y': '35.196390190449'}
# {'address_name': '인천 중구 북성동1가 산 1', 'category_group_code': 'AT4', 'category_group_name': '관광명소', 'category_name': '여행 > 관광,명소 > 섬 > 섬(내륙)', 'distance': '', 'id': '12461589', 'phone': '', 'place_name': '월미도', 'place_url': 'http://place.map.kakao.com/12461589', 'road_address_name': '', 'x': '126.599231057618', 'y': '37.4717375833542'}
# {'address_name': '인천 강화군 화도면 장화리 1351', 'category_group_code': 'AT4', 'category_group_name': '관광명소', 'category_name': '여행 > 관광,명소 > 전망대', 'distance': '', 'id': '26414858', 'phone': '', 'place_name': '장화리 일몰조망지', 'place_url': 'http://place.map.kakao.com/26414858', 'road_address_name': '', 'x': '126.377696641625', 'y': '37.6177544970921'}
# {'address_name': '강원 속초시 조양동 1450-143', 'category_group_code': 'AT4', 'category_group_name': '관광명소', 'category_name': '여행 > 관광,명소 > 테마파크', 'distance': '', 'id': '1501753360', 'phone': '0507-1482-0107', 'place_name': '속초아이', 'place_url': 'http://place.map.kakao.com/1501753360', 'road_address_name': '강원 속초시 청호해안길 2', 'x': '128.6026902136017', 'y': '38.19073872774693'}
# {'address_name': '경기 포천시 가산면 가산리 404-3', 'category_group_code': '', 'category_group_name': '', 'category_name': '가정,생활 > 유아 > 놀이시설', 'distance': '', 'id': '1614451602', 'phone': '010-9136-8670', 'place_name': '어린이 놀이기구 노리터', 'place_url': 'http://place.map.kakao.com/1614451602', 'road_address_name': '경기 포천시 가산면 시우동길 132', 'x': '127.170868907314', 'y': '37.8271473154182'}
# {'address_name': '경기 시흥시 정왕동 2030-11', 'category_group_code': 'FD6', 'category_group_name': '음식점', 'category_name': '음식점 > 한식 > 해물,생선 > 조개', 'distance': '', 'id': '27331019', 'phone': '031-319-5227', 'place_name': '청춘조개 본점', 'place_url': 'http://place.map.kakao.com/27331019', 'road_address_name': '경기 시흥시 오이도로 199-1', 'x': '126.68709741439', 'y': '37.3430350027099'}
# {'address_name': '인천 중구 북성동3가 5-3', 'category_group_code': 'FD6', 'category_group_name': '음식점', 'category_name': '음식점 > 중식 > 중국요리', 'distance': '', 'id': '8086891', 'phone': '032-772-5118', 'place_name': '청관', 'place_url': 'http://place.map.kakao.com/8086891', 'road_address_name': '인천 중구 차이나타운로 41-1', 'x': '126.619723180991', 'y': '37.475488617705'}
# {'address_name': '경남 김해시 삼문동 74-1', 'category_group_code': 'FD6', 'category_group_name': '음식점', 'category_name': '음식점 > 중식 > 중국요리', 'distance': '', 'id': '846617015', 'phone': '055-313-5989', 'place_name': '장유백짜장', 'place_url': 'http://place.map.kakao.com/846617015', 'road_address_name': '경남 김해시 능동로7번길 8-4', 'x': '128.794301290409', 'y': '35.196390190449'}
# {'address_name': '인천 중구 북성동1가 98-57', 'category_group_code': 'AT4', 'category_group_name': '관광명소', 'category_name': '여행 > 관광,명소 > 테마거리', 'distance': '', 'id': '18093723', 'phone': '032-764-0842', 'place_name': '월미문화의거리', 'place_url': 'http://place.map.kakao.com/18093723', 'road_address_name': '', 'x': '126.597841799787', 'y': '37.473621368634'}
# {'address_name': '인천 중구 북성동1가 98-333', 'category_group_code': 'AT4', 'category_group_name': '관광명소', 'category_name': '여행 > 관광,명소 > 테마파크', 'distance': '', 'id': '7866176', 'phone': '032-765-2490', 'place_name': '마이랜드', 'place_url': 'http://place.map.kakao.com/7866176', 'road_address_name': '인천 중구 월미로234번길 1', 'x': '126.598893429862', 'y': '37.474839496952'}
# {'address_name': '인천 부평구 부개동 496-20', 'category_group_code': '', 'category_group_name': '', 'category_name': '가정,생활 > 문구,사무용품', 'distance': '', 'id': '16096825', 'phone': '032-361-7573', 'place_name': '바이킹', 'place_url': 'http://place.map.kakao.com/16096825', 'road_address_name': '인천 부평구 길주남로 157', 'x': '126.739382657973', 'y': '37.5039857679468'}
# {'address_name': '경기 수원시 팔달구 매산로1가 37-1', 'category_group_code': '', 'category_group_name': '', 'category_name': '가정,생활 > 유흥시설', 'distance': '', 'id': '1864927281', 'phone': '', 'place_name': '디스코팡팡', 'place_url': 'http://place.map.kakao.com/1864927281', 'road_address_name': '경기 수원시 팔달구 갓매산로71번길 32', 'x': '127.003058700545', 'y': '37.2684258154594'}
# {'address_name': '강원 동해시 천곡동 918', 'category_group_code': 'AD5', 'category_group_name': '숙박', 'category_name': '여행 > 숙박 > 호텔', 'distance': '', 'id': '556838642', 'phone': '033-539-2023', 'place_name': '동해현진관광호텔 다이아몬드홀', 'place_url': 'http://place.map.kakao.com/556838642', 'road_address_name': '강원 동해시 동굴로 125-3', 'x': '129.117954934707', 'y': '37.5193033516232'}
# {'address_name': '부산 부산진구 연지동 190-65', 'category_group_code': 'PK6', 'category_group_name': '주차장', 'category_name': '교통,수송 > 교통시설 > 주차장', 'distance': '', 'id': '1595857119', 'phone': '', 'place_name': '대영탕맞은편 민영주차장', 'place_url': 'http://place.map.kakao.com/1595857119', 'road_address_name': '', 'x': '129.0519550756', 'y': '35.1705863082245'}
# {'address_name': '부산 부산진구 연지동 190-65', 'category_group_code': 'PK6', 'category_group_name': '주차장', 'category_name': '교통,수송 > 교통시설 > 주차장', 'distance': '', 'id': '1595857119', 'phone': '', 'place_name': '대영탕맞은편 민영주차장', 'place_url': 'http://place.map.kakao.com/1595857119', 'road_address_name': '', 'x': '129.0519550756', 'y': '35.1705863082245'}
# {'address_name': '경기 고양시 일산서구 대화동 2703', 'category_group_code': 'MT1', 'category_group_name': '대형마트', 'category_name': '가정,생활 > 대형마트 > 이마트', 'distance': '', 'id': '26506069', 'phone': '031-936-1123', 'place_name': '이마트타운 킨텍스점', 'place_url': 'http://place.map.kakao.com/26506069', 'road_address_name': '경기 고양시 일산서구 킨텍스로 171', 'x': '126.744118527802', 'y': '37.6616010946969'}
# {'address_name': '서울 종로구 세종로 1', 'category_group_code': '', 'category_group_name': '', 'category_name': '교통,수송 > 입출구', 'distance': '', 'id': '1867559637', 'phone': '', 'place_name': '청와대 정문', 'place_url': 'http://place.map.kakao.com/1867559637', 'road_address_name': '', 'x': '126.975240546822', 'y': '37.5843677021705'}
# {'address_name': '경기 고양시 일산서구 대화동 2703', 'category_group_code': 'MT1', 'category_group_name': '대형마트', 'category_name': '가정,생활 > 대형마트 > 이마트', 'distance': '', 'id': '26506069', 'phone': '031-936-1123', 'place_name': '이마트타운 킨텍스점', 'place_url': 'http://place.map.kakao.com/26506069', 'road_address_name': '경기 고양시 일산서구 킨텍스로 171', 'x': '126.744118527802', 'y': '37.6616010946969'}
# {'address_name': '경남 양산시 물금읍 물금리 894-4', 'category_group_code': 'FD6', 'category_group_name': '음식점', 'category_name': '음식점 > 양식', 'distance': '', 'id': '1695407647', 'phone': '', 'place_name': '버스타', 'place_url': 'http://place.map.kakao.com/1695407647', 'road_address_name': '경남 양산시 물금읍 청운로 48', 'x': '128.99246799443995', 'y': '35.307998896543225'}
# {'address_name': '경기 안성시 석정동 6-2', 'category_group_code': '', 'category_group_name': '', 'category_name': '가정,생활 > 식품판매', 'distance': '', 'id': '586268007', 'phone': '', 'place_name': '얼마요', 'place_url': 'http://place.map.kakao.com/586268007', 'road_address_name': '경기 안성시 중앙로367번길 8', 'x': '127.267849212608', 'y': '37.008103458463'}
# {'address_name': '부산 사하구 하단1동 617-17', 'category_group_code': 'FD6', 'category_group_name': '음식점', 'category_name': '음식점 > 한식 > 육류,고기', 'distance': '', 'id': '8430872', 'phone': '051-207-7852', 'place_name': '안가', 'place_url': 'http://place.map.kakao.com/8430872', 'road_address_name': '부산 사하구 낙동대로457번길 22', 'x': '128.967480448229', 'y': '35.1051783239147'}
# {'address_name': '충남 공주시 월미동', 'category_group_code': 'AT4', 'category_group_name': '관광명소', 'category_name': '여행 > 관광,명소 > 계곡', 'distance': '', 'id': '25291298', 'phone': '', 'place_name': '송산', 'place_url': 'http://place.map.kakao.com/25291298', 'road_address_name': '', 'x': '127.118456523918', 'y': '36.4901251164489'}
# {'address_name': '경기 김포시 운양동 1320-15', 'category_group_code': 'CE7', 'category_group_name': '카페', 'category_name': '음식점 > 카페 > 테마카페', 'distance': '', 'id': '567355795', 'phone': '031-981-5245', 'place_name': '별가까이', 'place_url': 'http://place.map.kakao.com/567355795', 'road_address_name': '경기 김포시 모담공원로167번길 101', 'x': '126.698960726717', 'y': '37.6472554144237'}
# {'address_name': '경남 양산시 물금읍 물금리 894-4', 'category_group_code': 'FD6', 'category_group_name': '음식점', 'category_name': '음식점 > 양식', 'distance': '', 'id': '1695407647', 'phone': '', 'place_name': '버스타', 'place_url': 'http://place.map.kakao.com/1695407647', 'road_address_name': '경남 양산시 물금읍 청운로 48', 'x': '128.99246799443995', 'y': '35.307998896543225'}
# {'address_name': '서울 종로구 종로3가 38-3', 'category_group_code': '', 'category_group_name': '', 'category_name': '가정,생활 > 패션 > 보석,귀금속', 'distance': '', 'id': '24529931', 'phone': '02-743-5937', 'place_name': '종로금방', 'place_url': 'http://place.map.kakao.com/24529931', 'road_address_name': '서울 종로구 종로 143-1', 'x': '126.99363835501771', 'y': '37.570763312115155'}
# {'address_name': '충북 괴산군 청천면 상신리 263-1', 'category_group_code': '', 'category_group_name': '', 'category_name': '여행 > 숙박', 'distance': '', 'id': '2659171', 'phone': '010-6336-3819', 'place_name': '너럭바위', 'place_url': 'http://place.map.kakao.com/2659171', 'road_address_name': '충북 괴산군 청천면 괴산로 349', 'x': '127.797554564147', 'y': '36.6252606118095'}
# {'address_name': '경기 성남시 중원구 성남동 2343', 'category_group_code': 'FD6', 'category_group_name': '음식점', 'category_name': '음식점', 'distance': '', 'id': '1696625387', 'phone': '', 'place_name': '완전', 'place_url': 'http://place.map.kakao.com/1696625387', 'road_address_name': '경기 성남시 중원구 광명로94번길 2', 'x': '127.139239535306', 'y': '37.4349125316986'}
# {'address_name': '경기 의정부시 가능동 산 81-2', 'category_group_code': 'AT4', 'category_group_name': '관광명소', 'category_name': '여행 > 관광,명소 > 계곡', 'distance': '', 'id': '18617143', 'phone': '', 'place_name': '안골계곡', 'place_url': 'http://place.map.kakao.com/18617143', 'road_address_name': '', 'x': '127.019777897326', 'y': '37.7253525682195'}
# {'address_name': '인천 미추홀구 주안동 6', 'category_group_code': '', 'category_group_name': '', 'category_name': '부동산 > 빌딩', 'distance': '', 'id': '841861727', 'phone': '', 'place_name': '도움빌딩', 'place_url': 'http://place.map.kakao.com/841861727', 'road_address_name': '인천 미추홀구 염전로 336', 'x': '126.677488373354', 'y': '37.4702075161722'}
# {'address_name': '서울 용산구 동빙고동 1-102', 'category_group_code': 'FD6', 'category_group_name': '음식점', 'category_name': '음식점 > 한식 > 한정식', 'distance': '', 'id': '17847794', 'phone': '02-792-1054', 'place_name': '오늘', 'place_url': 'http://place.map.kakao.com/17847794', 'road_address_name': '서울 용산구 장문로 60', 'x': '126.99603821346722', 'y': '37.52626309098107'}
# {'address_name': '제주특별자치도 제주시 영평동 2181', 'category_group_code': '', 'category_group_name': '', 'category_name': '서비스,산업 > 인터넷,IT > 포털서비스', 'distance': '', 'id': '18059921', 'phone': '1899-1326', 'place_name': '카카오 스페이스닷원', 'place_url': 'http://place.map.kakao.com/18059921', 'road_address_name': '제주특별자치도 제주시 첨단로 242', 'x': '126.57066130083415', 'y': '33.450682729588145'}
# {'address_name': '세종특별자치시 장군면 금암리 180-1', 'category_group_code': '', 'category_group_name': '', 'category_name': '교육,학문 > 학교 > 전문대학', 'distance': '', 'id': '8663308', 'phone': '044-850-9000', 'place_name': '한국영상대학교', 'place_url': 'http://place.map.kakao.com/8663308', 'road_address_name': '세종특별자치시 장군면 대학길 300', 'x': '127.20919616105093', 'y': '36.46358032130445'}
# {'address_name': '경북 울진군 울진읍 읍내리 529-5', 'category_group_code': '', 'category_group_name': '', 'category_name': '가정,생활 > 식품판매 > 반찬가게', 'distance': '', 'id': '1715508139', 'phone': '', 'place_name': '만나요', 'place_url': 'http://place.map.kakao.com/1715508139', 'road_address_name': '경북 울진군 울진읍 읍내5길 6-1', 'x': '129.40221503956', 'y': '36.9933642010866'}
# ['관광명소', '관광명소', '관광명소', '음식점', '관광명소', '관광명소', '', '']
#      placeID      pname             paddress pdo   psi        pphone  \
# 0   12706268    인천차이나타운       인천 중구 북성동2가 14  인천    중구  032-777-4000
# 1   12461589        월미도      인천 중구 북성동1가 산 1  인천    중구
# 2   26414858  장화리 일몰조망지  인천 강화군 화도면 장화리 1351  인천   강화군
# 3    8086891         청관      인천 중구 북성동3가 5-3  인천    중구  032-772-5118
# 4   18093723    월미문화의거리    인천 중구 북성동1가 98-57  인천    중구  032-764-0842
# 5    7866176       마이랜드   인천 중구 북성동1가 98-333  인천    중구  032-765-2490
# 6   16096825        바이킹    인천 부평구 부개동 496-20  인천   부평구  032-361-7573
# 7  841861727       도움빌딩        인천 미추홀구 주안동 6  인천  미추홀구
#
#                                pdaumURL                 pX                  pY
# 0   http://place.map.kakao.com/12706268  126.6186319858808  37.475536458050655
# 1   http://place.map.kakao.com/12461589   126.599231057618    37.4717375833542
# 2   http://place.map.kakao.com/26414858   126.377696641625    37.6177544970921
# 3    http://place.map.kakao.com/8086891   126.619723180991     37.475488617705
# 4   http://place.map.kakao.com/18093723   126.597841799787     37.473621368634
# 5    http://place.map.kakao.com/7866176   126.598893429862     37.474839496952
# 6   http://place.map.kakao.com/16096825   126.739382657973    37.5039857679468
# 7  http://place.map.kakao.com/841861727   126.677488373354    37.4702075161722

# %%
local = 'nexpot.c43ypw0liaa2.ap-northeast-2.rds.amazonaws.com'  # aws rds 접근
con = db.connect(
    host=local,
    user='admin',
    db='Nexpot',
    password='qwertyuiop123',
    charset='utf8'
)
cur = con.cursor()

# %%
for i in range(len(kakao_df)):   # places 테이블
    idx = f'{i+1}'
    sql = "insert into places values('" + idx + "','" + f'{vid}' + "','" + \
    kakao_df['placeID'][i] + "','" + kakao_df['pname'][i] + "','" + \
    kakao_df['paddress'][i] +"','" + kakao_df['pdo'][i] + "','" + \
    kakao_df['psi'][i] +"','" + kakao_df['pphone'][i] + "','" + kakao_df['pdaumURL'][i] +\
    "','" + kakao_df['pX'][i]+"','" + kakao_df['pY'][i] + "')"
    try:
        cur.execute(sql)
        con.commit()
    except:
        con.rollback()
        
con.close()
